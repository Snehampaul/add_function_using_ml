# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(42)

# %%
X_train = np.random.randint(0, 1000, size=(1000, 2))
y_train = X_train[:, 0] + X_train[:, 1]

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
x_test = np.random.randint(0,1000, size=(200,2))
y_test = x_test[:,0] + x_test[:,1]

# %%
predictions = model.predict(x_test)

# %%
predictions
# Out:
# array([1360., 1928.,  843., 1103.,  797.,  309., 1613.,  999.,  227.,
#         974., 1920., 1164.,  401., 1413., 1011., 1329., 1316.,  881.,
#         507.,  532., 1342., 1048.,  714.,  663., 1538.,  413., 1022.,
#        1628.,  851.,  985.,  793.,  991.,  967., 1186.,  614., 1190.,
#        1278.,  727., 1565.,  690.,  569., 1044.,  468., 1249., 1095.,
#        1652., 1558., 1214., 1231., 1102.,  990., 1056., 1317., 1515.,
#         757.,  644.,   71., 1069.,  862., 1334., 1153., 1519.,  883.,
#        1126.,  857.,  435., 1049., 1153., 1257., 1145., 1289.,  825.,
#         772., 1208.,  117., 1641., 1462.,  907., 1538.,  205.,  217.,
#         897., 1777., 1011.,  416., 1488.,  965.,  882., 1273., 1621.,
#        1188., 1114., 1068.,  689.,  501.,  796., 1348., 1208., 1097.,
#         364., 1150.,  776., 1366.,  351., 1659., 1759., 1564.,  152.,
#         523.,  665.,  811.,  889.,  904.,  897., 1720.,  549.,  361.,
#         502.,  443., 1140., 1495., 1142.,  900.,  861.,  545., 1087.,
#         705.,  878., 1381.,  790.,  959., 1064.,  798., 1219., 1007.,
#         612., 1305., 1511., 1255.,  747.,  711.,  344.,  375., 1087.,
#        1146., 1219.,  999.,  879., 1039.,  455., 1823.,  982.,  555.,
#        1024.,  472., 1778.,  724., 1053.,  207., 1440., 1305., 1589.,
#         494.,  328.,  574., 1389.,  999., 1437., 1173.,  839.,   34.,
#         938., 1523., 1005., 1404., 1551., 1018., 1166.,  799., 1074.,
#         884.,  308., 1682.,  230., 1682.,  815., 1056.,  479., 1244.,
#        1229., 1186., 1591.,  322., 1843., 1037., 1431., 1404.,  892.,
#         825., 1824.])

# %%
predictions = np.round(predictions).astype(int)

accuracy = np.mean(predictions == y_test) * 100

print("Accuracy:", accuracy, "%")
# Out:
# Accuracy: 100.0 %

# %%
result = model.predict([[25, 15]])

print("Answer:", round(result[0]))
# Out:
# Answer: 40
